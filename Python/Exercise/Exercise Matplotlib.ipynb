# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
åz = x**2

# %%
plt.plot(x,y)

# %%
fig  = plt.figure()
axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([.2,.5,.2,.2])
axes1.plot(x,y)
axes2.plot(x,y)
